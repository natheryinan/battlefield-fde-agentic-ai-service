# %%
import os
print(os.listdir("tiny_universe"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 print(os.listdir("tiny_universe"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'tiny_universe'

# %%
from pathlib import Path
import sys

PROJECT_ROOT = str(Path.cwd().resolve().parent)  # notebooks 的上一级就是项目根
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("PROJECT_ROOT =", PROJECT_ROOT)

# %%
from engine import FDEEngine

# %%
from engine import FDEEngine
from router import PersonaRouter

from fde.personas.alpha_multi import MultiFactorAlphaPersona
from fde.personas.convexity import ConvexityPersona

import importlib

import fde.personas.guardian
importlib.reload(fde.personas.guardian)

from fde.personas.guardian import GuardianPersona



alpha = MultiFactorAlphaPersona(config={"factor_names": ["value", "momentum"]})
convexity = ConvexityPersona(config={"sharpness": 2.0})
guardian = GuardianPersona()

router = PersonaRouter()

engine = FDEEngine(
    personas={
        "alpha": alpha,
        "convexity": convexity,
        "guardian": guardian,
    },
    router=router,
)

# %%
from src.api.engine_factory import build_engine

engine, mode, personas = build_engine()

print("Engine mode:", mode)

# %%
engine, mode, personas, router = build_engine(config={
    
})

final = engine.step(
    snapshot=snapshot,
    portfolio=portfolio,
    ctx=ctx,
    factors=factors,
)

# %%
import importlib
import fde.personas.guardian
import fde.router
import fde.policy.pm_policy

importlib.reload(fde.policy.pm_policy)
importlib.reload(fde.router)
importlib.reload(fde.personas.guardian)

from fde.personas.guardian import GuardianPersona
from fde.router import PersonaRouter
from fde.policy.pm_policy import choose_pm_profile
print("Reload OK ✓")

# %%
engine
